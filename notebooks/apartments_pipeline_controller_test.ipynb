# %%
import sys
import os

sys.path.append(os.path.join(os.getcwd(), '..'))

from pipeline_controller.pipeline_controller import PipelineController

# %%
controller = PipelineController(
    dataset_path="../datasets/warsaw_apartments.csv",
    target_column="m2_price",
    problem_type="regression",
    max_iterations=2,
    main_metric="rmse",
    optimization_goal="Choose the model with the lowest test RMSE.",
)

# %%
controller.run_full_pipeline()
# Out:
# 2025-06-02 13:32:31.099 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:152 -
# === [ITERATION 1] ===
# 2025-06-02 13:32:31.099 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:155 - [FeatureAgent] Starting feature selection...
# 2025-06-02 13:32:31.106 | INFO     | agents.feature_agent:run_feature_agent:220 - Feature Agent started with default parameters: max_features=10, selection_goal=maximise predictive power with the fewest features
# 2025-06-02 13:32:31.113 | INFO     | agents.feature_agent:run_feature_agent:224 - Processing request for dataset 'warsaw_apartments.csv'
# 2025-06-02 13:32:31.115 | INFO     | agents.feature_agent:run_feature_agent:233 - Computing basic stats...
# 2025-06-02 13:32:31.115 | INFO     | utils.mini_eda:compute_basic_stats:35 - Computing basic stats for 15 features
# 2025-06-02 13:32:31.173 | INFO     | utils.mini_eda:compute_basic_stats:101 - Basic stats computed for 15 features
# ...
