# %%
import os
import sys

sys.path.append(os.path.join(os.getcwd(), '..'))

from pipeline_controller.pipeline_controller import PipelineController

# %%
controller = PipelineController(
    dataset_path="../datasets/titanic.csv",
    target_column="Survived",
    problem_type="classification",
    max_iterations=3,
    main_metric="accuracy"
)
best_result = controller.run_full_pipeline()
# Out:
# 2025-06-02 12:58:08.751 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:139 -
# === [ITERATION 1] ===
# 2025-06-02 12:58:08.751 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:142 - [FeatureAgent] Starting feature selection...
# 2025-06-02 12:58:08.757 | INFO     | agents.feature_agent:run_feature_agent:220 - Feature Agent started with default parameters: max_features=10, selection_goal=maximise predictive power with the fewest features
# 2025-06-02 12:58:08.757 | INFO     | agents.feature_agent:run_feature_agent:224 - Processing request for dataset 'titanic.csv'
# 2025-06-02 12:58:08.763 | INFO     | agents.feature_agent:run_feature_agent:233 - Computing basic stats...
# 2025-06-02 12:58:08.763 | INFO     | utils.mini_eda:compute_basic_stats:35 - Computing basic stats for 12 features
# 2025-06-02 12:58:08.776 | INFO     | utils.mini_eda:compute_basic_stats:101 - Basic stats computed for 12 features
# 2025-06-02 12:58:08.790 | INFO     | agents.feature_agent:run_feature_agent:243 - Top MI-recommended features: ['Fare', 'Pclass', 'PassengerId', 'SibSp', 'Parch', 'Age']
# 2025-06-02 12:58:08.793 | INFO     | agents.feature_agent:run_feature_agent:247 - Prompt length: 2697 characters
# 2025-06-02 12:58:16.285 | INFO     | agents.feature_agent:run_feature_agent:251 - LLM response received successfully
# 2025-06-02 12:58:16.290 | INFO     | agents.feature_agent:_build_pipeline_blob:299 - Pipeline blob generated with 41941 bytes
# 2025-06-02 12:58:16.291 | INFO     | agents.feature_agent:run_feature_agent:257 - Pipeline serialized to 55924 bytes
# 2025-06-02 12:58:16.292 | INFO     | agents.feature_agent:run_feature_agent:264 - Feature Agent finished after 7.53 seconds. Selected features: ['Sex', 'Fare', 'Pclass', 'PassengerId', 'SibSp', 'Parch', 'Age']
# 2025-06-02 12:58:16.292 | INFO     | agents.feature_agent:run_feature_agent:266 - Reasoning: Selected features based on a combination of high mutual information scores and relevance to the target variable 'Survived'. Sex, as the most informative feature, has a strong correlation with survival. Fare and Pclass are also significant predictors of survival. PassengerId, SibSp, Parch, and Age were selected to provide additional information and potential interactions with other features.
# 2025-06-02 12:58:16.293 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:145 - [FeatureAgent] Finished in 7.54s. Selected: ['Sex', 'Fare', 'Pclass', 'PassengerId', 'SibSp', 'Parch', 'Age']
# 2025-06-02 12:58:16.294 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:146 - [FeatureAgent] Reasoning:
# Selected features based on a combination of high mutual information scores and relevance to the target variable 'Survived'. Sex, as the most informative feature, has a strong correlation with survival. Fare and Pclass are also significant predictors of survival. PassengerId, SibSp, Parch, and Age were selected to provide additional information and potential interactions with other features.
# 2025-06-02 12:58:16.294 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:149 - [ModelAgent] Starting model selection...
# 2025-06-02 12:58:16.296 | INFO     | agents.model_selection_agent:run_model_agent:137 - Model Selection Agent started with default parameters.
# 2025-06-02 12:58:16.296 | INFO     | agents.model_selection_agent:run_model_agent:139 - Processing request for dataset 'titanic.csv'
# 2025-06-02 12:58:16.297 | INFO     | agents.model_selection_agent:_build_prompt:81 - Building the prompt for model selection.
# 2025-06-02 12:58:16.297 | INFO     | agents.model_selection_agent:run_model_agent:143 - Prompt length: 184 characters
# 2025-06-02 12:58:18.337 | INFO     | agents.model_selection_agent:run_model_agent:148 - LLM response received successfully
# 2025-06-02 12:58:18.349 | INFO     | agents.model_selection_agent:run_model_agent:154 - Pipeline serialized to {len(pipe_blob)} bytes
# 2025-06-02 12:58:18.350 | INFO     | agents.model_selection_agent:run_model_agent:161 - Model Selection Agent finished after 2.05 seconds. Selected model: ModelEnum.RANDOMFOREST, hyperparameters: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 6}
# 2025-06-02 12:58:18.350 | INFO     | agents.model_selection_agent:run_model_agent:163 - Reasoning: Random Forests are robust to noise and missing data, and they can handle both numerical and categorical features well. The dataset contains a mix of feature types, making Random Forest a suitable choice for this classification task.
# 2025-06-02 12:58:18.351 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:152 - [ModelAgent] Finished in 2.06s. Selected: ModelEnum.RANDOMFOREST with {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 6}
# 2025-06-02 12:58:18.351 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:153 - [ModelAgent] Reasoning:
# Random Forests are robust to noise and missing data, and they can handle both numerical and categorical features well. The dataset contains a mix of feature types, making Random Forest a suitable choice for this classification task.
# 2025-06-02 12:58:18.352 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:155 - [Training] Training and evaluating model...
# 2025-06-02 12:58:18.462 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:157 - [Training] Metrics: {'train_accuracy': 0.8707865168539326, 'test_accuracy': 0.7988826815642458, 'train_precision': 0.9112149532710281, 'test_precision': 0.8064516129032258, 'train_recall': 0.7276119402985075, 'test_recall': 0.6756756756756757, 'train_f1_score': 0.8091286307053942, 'test_f1_score': 0.7352941176470589}
# 2025-06-02 12:58:18.463 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:160 - [EvaluationAgent] Starting evaluation...
# 2025-06-02 12:58:18.463 | INFO     | agents.evaluation_agent:run_evaluation_agent:135 - Evaluation Agent started processing.
# 2025-06-02 12:58:18.463 | INFO     | agents.evaluation_agent:run_evaluation_agent:136 - Running evaluation agent for dataset 'titanic.csv'
# 2025-06-02 12:58:18.464 | INFO     | agents.evaluation_agent:run_evaluation_agent:148 - Prompt length: 661 characters
# 2025-06-02 12:58:19.703 | INFO     | agents.evaluation_agent:run_evaluation_agent:153 - Evaluation Agent finished after 1.24 seconds. Recommendation: continue
# 2025-06-02 12:58:19.705 | INFO     | agents.evaluation_agent:run_evaluation_agent:155 - Reasoning: The model shows decent performance with test metrics above 0.70 and a relatively small gap between train and test metrics. Continuing training with the current model is justified to further improve performance.
# 2025-06-02 12:58:19.705 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:163 - [EvaluationAgent] Finished in 1.24s. Recommendation: continue, Confidence: 0.8
# 2025-06-02 12:58:19.706 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:164 - [EvaluationAgent] Reasoning:
# The model shows decent performance with test metrics above 0.70 and a relatively small gap between train and test metrics. Continuing training with the current model is justified to further improve performance.
# 2025-06-02 12:58:19.707 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:179 - [EvaluationAgent] Iteration conclusions:
# Iteration 1 conclusions:
#
# Features selected: Sex, Fare, Pclass, PassengerId, SibSp, Parch, Age
# Model: ModelEnum.RANDOMFOREST
# Hyperparameters: n_estimators=100, criterion=gini, max_depth=6
# Evaluation conclusion: The model shows decent performance with test metrics above 0.70 and a relatively small gap between train and test metrics. Continuing training with the current model is justified to further improve performance.
# Recommendation: continue
# Confidence: 0.8
# 2025-06-02 12:58:19.709 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:180 - [EvaluationAgent] Full evaluation conclusions:
# Iteration 1 conclusions:
#
# Features selected: Sex, Fare, Pclass, PassengerId, SibSp, Parch, Age
# Model: ModelEnum.RANDOMFOREST
# Hyperparameters: n_estimators=100, criterion=gini, max_depth=6
# Evaluation conclusion: The model shows decent performance with test metrics above 0.70 and a relatively small gap between train and test metrics. Continuing training with the current model is justified to further improve performance.
# Recommendation: continue
# Confidence: 0.8
# 2025-06-02 12:58:19.709 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:139 -
# === [ITERATION 2] ===
# 2025-06-02 12:58:19.710 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:142 - [FeatureAgent] Starting feature selection...
# 2025-06-02 12:58:19.714 | INFO     | agents.feature_agent:run_feature_agent:220 - Feature Agent started with default parameters: max_features=10, selection_goal=maximise predictive power with the fewest features
# 2025-06-02 12:58:19.714 | INFO     | agents.feature_agent:run_feature_agent:224 - Processing request for dataset 'titanic.csv'
# 2025-06-02 12:58:19.719 | INFO     | agents.feature_agent:run_feature_agent:233 - Computing basic stats...
# 2025-06-02 12:58:19.720 | INFO     | utils.mini_eda:compute_basic_stats:35 - Computing basic stats for 12 features
# 2025-06-02 12:58:19.736 | INFO     | utils.mini_eda:compute_basic_stats:101 - Basic stats computed for 12 features
# 2025-06-02 12:58:19.749 | INFO     | agents.feature_agent:run_feature_agent:243 - Top MI-recommended features: ['Fare', 'PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch']
# 2025-06-02 12:58:19.751 | INFO     | agents.feature_agent:run_feature_agent:247 - Prompt length: 3227 characters
# 2025-06-02 12:58:28.072 | INFO     | agents.feature_agent:run_feature_agent:251 - LLM response received successfully
# 2025-06-02 12:58:28.077 | INFO     | agents.feature_agent:_build_pipeline_blob:299 - Pipeline blob generated with 41942 bytes
# 2025-06-02 12:58:28.078 | INFO     | agents.feature_agent:run_feature_agent:257 - Pipeline serialized to 55924 bytes
# 2025-06-02 12:58:28.079 | INFO     | agents.feature_agent:run_feature_agent:264 - Feature Agent finished after 8.36 seconds. Selected features: ['Sex', 'Fare', 'Pclass', 'PassengerId', 'SibSp', 'Parch', 'Age']
# 2025-06-02 12:58:28.080 | INFO     | agents.feature_agent:run_feature_agent:266 - Reasoning: The features Sex, Fare, Pclass, PassengerId, SibSp, Parch, and Age were selected based on their importance from mutual information, previous evaluation conclusions, and their diversity in terms of data types and potential interaction effects. These features have shown to be important for the model's performance, with Sex providing categorical information, and the others offering numeric characteristics that are relevant for predicting survival on the Titanic.
# 2025-06-02 12:58:28.081 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:145 - [FeatureAgent] Finished in 8.37s. Selected: ['Sex', 'Fare', 'Pclass', 'PassengerId', 'SibSp', 'Parch', 'Age']
# 2025-06-02 12:58:28.081 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:146 - [FeatureAgent] Reasoning:
# The features Sex, Fare, Pclass, PassengerId, SibSp, Parch, and Age were selected based on their importance from mutual information, previous evaluation conclusions, and their diversity in terms of data types and potential interaction effects. These features have shown to be important for the model's performance, with Sex providing categorical information, and the others offering numeric characteristics that are relevant for predicting survival on the Titanic.
# 2025-06-02 12:58:28.082 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:149 - [ModelAgent] Starting model selection...
# 2025-06-02 12:58:28.084 | INFO     | agents.model_selection_agent:run_model_agent:137 - Model Selection Agent started with default parameters.
# 2025-06-02 12:58:28.084 | INFO     | agents.model_selection_agent:run_model_agent:139 - Processing request for dataset 'titanic.csv'
# 2025-06-02 12:58:28.085 | INFO     | agents.model_selection_agent:_build_prompt:81 - Building the prompt for model selection.
# 2025-06-02 12:58:28.085 | INFO     | agents.model_selection_agent:run_model_agent:143 - Prompt length: 713 characters
# 2025-06-02 12:58:31.078 | INFO     | agents.model_selection_agent:run_model_agent:148 - LLM response received successfully
# 2025-06-02 12:58:31.083 | INFO     | agents.model_selection_agent:run_model_agent:154 - Pipeline serialized to {len(pipe_blob)} bytes
# 2025-06-02 12:58:31.084 | INFO     | agents.model_selection_agent:run_model_agent:161 - Model Selection Agent finished after 3.00 seconds. Selected model: ModelEnum.GRADIENTBOOSTING, hyperparameters: {'n_estimators': 150, 'learning_rate': 0.05}
# 2025-06-02 12:58:31.084 | INFO     | agents.model_selection_agent:run_model_agent:163 - Reasoning: The Random Forest model performed well in the previous iteration with decent test metrics and minimal overfitting. Switching to Gradient Boosting may provide a boost in accuracy and generalization, with a focus on preventing overfitting by tuning hyperparameters.
# 2025-06-02 12:58:31.085 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:152 - [ModelAgent] Finished in 3.00s. Selected: ModelEnum.GRADIENTBOOSTING with {'n_estimators': 150, 'learning_rate': 0.05}
# 2025-06-02 12:58:31.085 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:153 - [ModelAgent] Reasoning:
# The Random Forest model performed well in the previous iteration with decent test metrics and minimal overfitting. Switching to Gradient Boosting may provide a boost in accuracy and generalization, with a focus on preventing overfitting by tuning hyperparameters.
# 2025-06-02 12:58:31.086 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:155 - [Training] Training and evaluating model...
# 2025-06-02 12:58:31.223 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:157 - [Training] Metrics: {'train_accuracy': 0.8904494382022472, 'test_accuracy': 0.8044692737430168, 'train_precision': 0.9166666666666666, 'test_precision': 0.819672131147541, 'train_recall': 0.7798507462686567, 'test_recall': 0.6756756756756757, 'train_f1_score': 0.842741935483871, 'test_f1_score': 0.7407407407407407}
# 2025-06-02 12:58:31.223 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:160 - [EvaluationAgent] Starting evaluation...
# 2025-06-02 12:58:31.224 | INFO     | agents.evaluation_agent:run_evaluation_agent:135 - Evaluation Agent started processing.
# 2025-06-02 12:58:31.224 | INFO     | agents.evaluation_agent:run_evaluation_agent:136 - Running evaluation agent for dataset 'titanic.csv'
# 2025-06-02 12:58:31.225 | INFO     | agents.evaluation_agent:run_evaluation_agent:148 - Prompt length: 825 characters
# 2025-06-02 12:58:32.782 | INFO     | agents.evaluation_agent:run_evaluation_agent:153 - Evaluation Agent finished after 1.56 seconds. Recommendation: continue
# 2025-06-02 12:58:32.783 | INFO     | agents.evaluation_agent:run_evaluation_agent:155 - Reasoning: The model shows improvement in test metrics with a small gap between train/test performance. Although test recall is below 0.70, the gap is not significant, and the model is moving in the right direction. Continuing training with the current model is justified.
# 2025-06-02 12:58:32.784 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:163 - [EvaluationAgent] Finished in 1.56s. Recommendation: continue, Confidence: 0.8
# 2025-06-02 12:58:32.786 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:164 - [EvaluationAgent] Reasoning:
# The model shows improvement in test metrics with a small gap between train/test performance. Although test recall is below 0.70, the gap is not significant, and the model is moving in the right direction. Continuing training with the current model is justified.
# 2025-06-02 12:58:32.787 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:179 - [EvaluationAgent] Iteration conclusions:
# Iteration 2 conclusions:
#
# Features selected: Sex, Fare, Pclass, PassengerId, SibSp, Parch, Age
# Model: ModelEnum.GRADIENTBOOSTING
# Hyperparameters: n_estimators=150, learning_rate=0.05
# Evaluation conclusion: The model shows improvement in test metrics with a small gap between train/test performance. Although test recall is below 0.70, the gap is not significant, and the model is moving in the right direction. Continuing training with the current model is justified.
# Recommendation: continue
# Confidence: 0.8
# 2025-06-02 12:58:32.788 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:180 - [EvaluationAgent] Full evaluation conclusions:
# Iteration 1 conclusions:
#
# Features selected: Sex, Fare, Pclass, PassengerId, SibSp, Parch, Age
# Model: ModelEnum.RANDOMFOREST
# Hyperparameters: n_estimators=100, criterion=gini, max_depth=6
# Evaluation conclusion: The model shows decent performance with test metrics above 0.70 and a relatively small gap between train and test metrics. Continuing training with the current model is justified to further improve performance.
# Recommendation: continue
# Confidence: 0.8
#
# Iteration 2 conclusions:
#
# Features selected: Sex, Fare, Pclass, PassengerId, SibSp, Parch, Age
# Model: ModelEnum.GRADIENTBOOSTING
# Hyperparameters: n_estimators=150, learning_rate=0.05
# Evaluation conclusion: The model shows improvement in test metrics with a small gap between train/test performance. Although test recall is below 0.70, the gap is not significant, and the model is moving in the right direction. Continuing training with the current model is justified.
# Recommendation: continue
# Confidence: 0.8
# 2025-06-02 12:58:32.788 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:139 -
# === [ITERATION 3] ===
# 2025-06-02 12:58:32.789 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:142 - [FeatureAgent] Starting feature selection...
# 2025-06-02 12:58:32.793 | INFO     | agents.feature_agent:run_feature_agent:220 - Feature Agent started with default parameters: max_features=10, selection_goal=maximise predictive power with the fewest features
# 2025-06-02 12:58:32.793 | INFO     | agents.feature_agent:run_feature_agent:224 - Processing request for dataset 'titanic.csv'
# 2025-06-02 12:58:32.799 | INFO     | agents.feature_agent:run_feature_agent:233 - Computing basic stats...
# 2025-06-02 12:58:32.800 | INFO     | utils.mini_eda:compute_basic_stats:35 - Computing basic stats for 12 features
# 2025-06-02 12:58:32.816 | INFO     | utils.mini_eda:compute_basic_stats:101 - Basic stats computed for 12 features
# 2025-06-02 12:58:32.829 | INFO     | agents.feature_agent:run_feature_agent:243 - Top MI-recommended features: ['Fare', 'Pclass', 'SibSp', 'PassengerId', 'Parch', 'Age']
# 2025-06-02 12:58:32.831 | INFO     | agents.feature_agent:run_feature_agent:247 - Prompt length: 3737 characters
# 2025-06-02 12:58:47.661 | INFO     | agents.feature_agent:run_feature_agent:251 - LLM response received successfully
# 2025-06-02 12:58:47.666 | INFO     | agents.feature_agent:_build_pipeline_blob:299 - Pipeline blob generated with 41942 bytes
# 2025-06-02 12:58:47.667 | INFO     | agents.feature_agent:run_feature_agent:257 - Pipeline serialized to 55924 bytes
# 2025-06-02 12:58:47.668 | INFO     | agents.feature_agent:run_feature_agent:264 - Feature Agent finished after 14.87 seconds. Selected features: ['Sex', 'Fare', 'Pclass', 'PassengerId', 'SibSp', 'Parch', 'Age']
# 2025-06-02 12:58:47.668 | INFO     | agents.feature_agent:run_feature_agent:266 - Reasoning: Selected features based on their consistent importance in previous iterations with different models. The features include Sex, Fare, Pclass, PassengerId, SibSp, Parch, and Age, providing a balanced mix of categorical and numeric information for classification. These features are critical for maintaining predictive power while ensuring interpretability and model performance.
# 2025-06-02 12:58:47.669 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:145 - [FeatureAgent] Finished in 14.88s. Selected: ['Sex', 'Fare', 'Pclass', 'PassengerId', 'SibSp', 'Parch', 'Age']
# 2025-06-02 12:58:47.670 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:146 - [FeatureAgent] Reasoning:
# Selected features based on their consistent importance in previous iterations with different models. The features include Sex, Fare, Pclass, PassengerId, SibSp, Parch, and Age, providing a balanced mix of categorical and numeric information for classification. These features are critical for maintaining predictive power while ensuring interpretability and model performance.
# 2025-06-02 12:58:47.671 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:149 - [ModelAgent] Starting model selection...
# 2025-06-02 12:58:47.672 | INFO     | agents.model_selection_agent:run_model_agent:137 - Model Selection Agent started with default parameters.
# 2025-06-02 12:58:47.673 | INFO     | agents.model_selection_agent:run_model_agent:139 - Processing request for dataset 'titanic.csv'
# 2025-06-02 12:58:47.673 | INFO     | agents.model_selection_agent:_build_prompt:81 - Building the prompt for model selection.
# 2025-06-02 12:58:47.674 | INFO     | agents.model_selection_agent:run_model_agent:143 - Prompt length: 1223 characters
# 2025-06-02 12:58:50.226 | INFO     | agents.model_selection_agent:run_model_agent:148 - LLM response received successfully
# 2025-06-02 12:58:50.236 | INFO     | agents.model_selection_agent:run_model_agent:154 - Pipeline serialized to {len(pipe_blob)} bytes
# 2025-06-02 12:58:50.237 | INFO     | agents.model_selection_agent:run_model_agent:161 - Model Selection Agent finished after 2.56 seconds. Selected model: ModelEnum.LOGISTICREGRESSION, hyperparameters: {}
# 2025-06-02 12:58:50.237 | INFO     | agents.model_selection_agent:run_model_agent:163 - Reasoning: Given the past evaluation results, both RandomForest and GradientBoosting have been tried. LogisticRegression, being a simpler model, may provide additional insights into feature importance and improve interpretability. It can handle the selected features well and may offer a different perspective on the dataset.
# 2025-06-02 12:58:50.238 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:152 - [ModelAgent] Finished in 2.57s. Selected: ModelEnum.LOGISTICREGRESSION with {}
# 2025-06-02 12:58:50.238 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:153 - [ModelAgent] Reasoning:
# Given the past evaluation results, both RandomForest and GradientBoosting have been tried. LogisticRegression, being a simpler model, may provide additional insights into feature importance and improve interpretability. It can handle the selected features well and may offer a different perspective on the dataset.
# 2025-06-02 12:58:50.239 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:155 - [Training] Training and evaluating model...
# 2025-06-02 12:58:50.271 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:157 - [Training] Metrics: {'train_accuracy': 0.797752808988764, 'test_accuracy': 0.8044692737430168, 'train_precision': 0.7540983606557377, 'test_precision': 0.7910447761194029, 'train_recall': 0.6865671641791045, 'test_recall': 0.7162162162162162, 'train_f1_score': 0.71875, 'test_f1_score': 0.75177304964539}
# 2025-06-02 12:58:50.271 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:160 - [EvaluationAgent] Starting evaluation...
# 2025-06-02 12:58:50.272 | INFO     | agents.evaluation_agent:run_evaluation_agent:135 - Evaluation Agent started processing.
# 2025-06-02 12:58:50.272 | INFO     | agents.evaluation_agent:run_evaluation_agent:136 - Running evaluation agent for dataset 'titanic.csv'
# 2025-06-02 12:58:50.273 | INFO     | agents.evaluation_agent:run_evaluation_agent:148 - Prompt length: 985 characters
# 2025-06-02 12:58:51.506 | INFO     | agents.evaluation_agent:run_evaluation_agent:153 - Evaluation Agent finished after 1.23 seconds. Recommendation: continue
# 2025-06-02 12:58:51.506 | INFO     | agents.evaluation_agent:run_evaluation_agent:155 - Reasoning: The model is performing consistently with a slight improvement in test metrics. The gap between train and test metrics is acceptable, indicating no signs of overfitting. Continuing with the current model is justified.
# 2025-06-02 12:58:51.507 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:163 - [EvaluationAgent] Finished in 1.24s. Recommendation: continue, Confidence: 0.8
# 2025-06-02 12:58:51.508 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:164 - [EvaluationAgent] Reasoning:
# The model is performing consistently with a slight improvement in test metrics. The gap between train and test metrics is acceptable, indicating no signs of overfitting. Continuing with the current model is justified.
# 2025-06-02 12:58:51.508 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:179 - [EvaluationAgent] Iteration conclusions:
# Iteration 3 conclusions:
#
# Features selected: Sex, Fare, Pclass, PassengerId, SibSp, Parch, Age
# Model: ModelEnum.LOGISTICREGRESSION
# Hyperparameters:
# Evaluation conclusion: The model is performing consistently with a slight improvement in test metrics. The gap between train and test metrics is acceptable, indicating no signs of overfitting. Continuing with the current model is justified.
# Recommendation: continue
# Confidence: 0.8
# 2025-06-02 12:58:51.509 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:180 - [EvaluationAgent] Full evaluation conclusions:
# Iteration 1 conclusions:
#
# Features selected: Sex, Fare, Pclass, PassengerId, SibSp, Parch, Age
# Model: ModelEnum.RANDOMFOREST
# Hyperparameters: n_estimators=100, criterion=gini, max_depth=6
# Evaluation conclusion: The model shows decent performance with test metrics above 0.70 and a relatively small gap between train and test metrics. Continuing training with the current model is justified to further improve performance.
# Recommendation: continue
# Confidence: 0.8
#
# Iteration 2 conclusions:
#
# Features selected: Sex, Fare, Pclass, PassengerId, SibSp, Parch, Age
# Model: ModelEnum.GRADIENTBOOSTING
# Hyperparameters: n_estimators=150, learning_rate=0.05
# Evaluation conclusion: The model shows improvement in test metrics with a small gap between train/test performance. Although test recall is below 0.70, the gap is not significant, and the model is moving in the right direction. Continuing training with the current model is justified.
# Recommendation: continue
# Confidence: 0.8
#
# Iteration 3 conclusions:
#
# Features selected: Sex, Fare, Pclass, PassengerId, SibSp, Parch, Age
# Model: ModelEnum.LOGISTICREGRESSION
# Hyperparameters:
# Evaluation conclusion: The model is performing consistently with a slight improvement in test metrics. The gap between train and test metrics is acceptable, indicating no signs of overfitting. Continuing with the current model is justified.
# Recommendation: continue
# Confidence: 0.8
# 2025-06-02 12:58:51.509 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:206 -
# === [BEST MODEL SUMMARY] ===
# 2025-06-02 12:58:51.510 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:208 - Best model: ModelEnum.GRADIENTBOOSTING
# 2025-06-02 12:58:51.510 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:209 - Hyperparameters: {'n_estimators': 150, 'learning_rate': 0.05}
# 2025-06-02 12:58:51.511 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:210 - Features: ['Sex', 'Fare', 'Pclass', 'PassengerId', 'SibSp', 'Parch', 'Age']
# 2025-06-02 12:58:51.512 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:211 - Test accuracy: 0.8045
# 2025-06-02 12:58:51.512 | INFO     | pipeline_controller.pipeline_controller:run_full_pipeline:212 - Reasoning: The model shows improvement in test metrics with a small gap between train/test performance. Although test recall is below 0.70, the gap is not significant, and the model is moving in the right direction. Continuing training with the current model is justified.

# %%
best_result
# Out:
# {'metrics': {'train_accuracy': 0.8904494382022472,
#   'test_accuracy': 0.8044692737430168,
#   'train_precision': 0.9166666666666666,
#   'test_precision': 0.819672131147541,
#   'train_recall': 0.7798507462686567,
#   'test_recall': 0.6756756756756757,
#   'train_f1_score': 0.842741935483871,
#   'test_f1_score': 0.7407407407407407},
#  'model_name': <ModelEnum.GRADIENTBOOSTING: 'GradientBoosting'>,
#  'hyperparameters': {'n_estimators': 150, 'learning_rate': 0.05},
#  'features': ['Sex', 'Fare', 'Pclass', 'PassengerId', 'SibSp', 'Parch', 'Age'],
#  'reasoning': 'The model shows improvement in test metrics with a small gap between train/test performance. Although test recall is below 0.70, the gap is not significant, and the model is moving in the right direction. Continuing training with the current model is justified.',
#  'recommendation': 'continue'}

# %%
model = controller.pipeline

print(model)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['Fare', 'Pclass',
#                                                    'PassengerId', 'SibSp',
#                                                    'Parch', 'Age']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encode',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Sex'])])),
#                 ('model', LogisticRegression())])
